# %% [markdown]
# ### Dataset
#
# Synthetic Financial Datasets For Fraud Detection
#
# Synthetic datasets generated by the PaySim mobile money simulator - from Kaggle <https://www.kaggle.com/datasets/ealaxi/paysim1>

# %% [markdown]
# This dataset is about 500mb -  CSV File - select just 100 rows and transform to parquet for a better performance

# %%
import pandas as pd
import fastparquet

# %%
# Carregar CSV em Pandas
df = pd.read_parquet("/Users/rafa/pipeline1/data/transactions.parquet")

# %%
len(df)
# Out:
# 6362620

# %%
df_sample = df.head(100)
len(df_sample)
# Out:
# 100

# %%
df_sample.to_parquet("/Users/rafa/pipeline1/data/transactionsv2.parquet", engine="fastparquet")
